# %% [markdown]
# # Habitable Exoplanets Predictions

# %% [markdown]
# ## Introduction
#
# This project is using the exoplanets archive from NASA website containing multiple features of the exoplanets and labels to predict whether it is habitable or not.
#
#
# ![image.png](attachment:image.png)
#
#
#
#
#
# **What is an exoplanet?**
#
# An exoplanet is a planet outside of our solar system that normally orbits a star other than our own sun in our galaxy.
#
#
# **What is a habitable exoplanet?**
#
# The standard definition for a habitable planet is one that can sustain life for a significant period of time.

# %%
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
